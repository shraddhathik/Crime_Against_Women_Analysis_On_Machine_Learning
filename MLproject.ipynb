# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Read File

# %%
df=pd.read_csv("CrimesOnWomenData.csv")

# %% [markdown]
# Content Of Dataset

# %%
df
# Out:
#      Unnamed: 0              State  Year  Rape  Kidnap And Assault  \
# 0             0     ANDHRA PRADESH  2001   871                 765
# 1             1  ARUNACHAL PRADESH  2001    33                  55
# 2             2              ASSAM  2001   817                1070
# 3             3              BIHAR  2001   888                 518
# 4             4       CHHATTISGARH  2001   959                 171
# ..          ...                ...   ...   ...                 ...
# 731         731         D&N Haveli  2021  1250                4083
# 732         732        Daman & Diu  2021   315                 904
# 733         733           Delhi UT  2021     2                   1
# 734         734        Lakshadweep  2021     0                   0
# 735         735         Puducherry  2021     2                   0
#
#      Dowry Deaths  Assault against women  Assault against modesty of women  \
# 0             420                   3544                              2271
# ...

# %%
# To get overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        736 non-null    int64
#  1   State                             736 non-null    object
#  2   Year                              736 non-null    int64
#  3   Rape                              736 non-null    int64
#  4   Kidnap And Assault                736 non-null    int64
#  5   Dowry Deaths                      736 non-null    int64
#  6   Assault against women             736 non-null    int64
#  7   Assault against modesty of women  736 non-null    int64
#  8   Domestic violence                 736 non-null    int64
#  9   Women Trafficking                 736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %%
# Checking the type of dataset
df.dtypes
# Out:
# Unnamed: 0                           int64
# State                               object
# Year                                 int64
# Rape                                 int64
# Kidnap And Assault                   int64
# Dowry Deaths                         int64
# Assault against women                int64
# Assault against modesty of women     int64
# Domestic violence                    int64
# Women Trafficking                    int64
# dtype: object

# %%
#checking null values from dataset
df.isna().sum()
# Out:
# Unnamed: 0                          0
# State                               0
# Year                                0
# Rape                                0
# Kidnap And Assault                  0
# Dowry Deaths                        0
# Assault against women               0
# Assault against modesty of women    0
# Domestic violence                   0
# Women Trafficking                   0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0              State  Year  Rape  Kidnap And Assault  \
# 0           0     ANDHRA PRADESH  2001   871                 765
# 1           1  ARUNACHAL PRADESH  2001    33                  55
# 2           2              ASSAM  2001   817                1070
# 3           3              BIHAR  2001   888                 518
# 4           4       CHHATTISGARH  2001   959                 171
#
#    Dowry Deaths  Assault against women  Assault against modesty of women  \
# 0           420                   3544                              2271
# 1             0                     78                                 3
# 2            59                    850                                 4
# 3           859                    562                                21
# 4            70                   1763                               161
#
#    Domestic violence  Women Trafficking
# 0               5791                  7
# 1                 11                  0
# ...

# %%
# Checking how many columns are there in the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Year', 'Rape', 'Kidnap And Assault',
#        'Dowry Deaths', 'Assault against women',
#        'Assault against modesty of women', 'Domestic violence',
#        'Women Trafficking'],
#       dtype='object')

# %%
#removing the column from dataset
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
#lenght of states from dataset
print(df["State"].unique())
len(df["State"].unique())
# Out:
# ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'LAKSHADWEEP' 'PUDUCHERRY'
#  'Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Goa'
#  'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand'
#  'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Mizoram' 'Nagaland' 'Odisha' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu'
#  'Telangana' 'Tripura' 'Uttar Pradesh' 'Uttarakhand' 'West Bengal'
#  'A & N Islands' 'Chandigarh' 'D&N Haveli' 'Daman & Diu' 'Delhi UT'
#  'Lakshadweep' 'Puducherry']
# 70

# %% [markdown]
# We have total of 70 distinct elements in our State column, which indicates that some entries are repeated like D & N HAVELI and D&N Haveli

# %%
#Removing repeated entries
def get_case_consistency(row):
    row = row["State"].strip()
    row = row.upper()
    #row = row.title()
    return row

df["State"] = df.apply(get_case_consistency, axis=1)

df["State"].replace("A&N ISLANDS", "A & N ISLANDS", inplace = True)
df["State"].replace("D&N HAVELI", "D & N HAVELI", inplace = True)
df["State"].replace("DELHI UT", "DELHI", inplace = True)
df["State"].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'LAKSHADWEEP', 'PUDUCHERRY', 'TELANGANA', 'DELHI'],
#       dtype=object)

# %%
len(df["State"].unique())
# Out:
# 36

# %%
# checking duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking number of unique values in each column
df.nunique()
# Out:
# State                                36
# Year                                 21
# Rape                                498
# Kidnap And Assault                  491
# Dowry Deaths                        319
# Assault against women               505
# Assault against modesty of women    322
# Domestic violence                   488
# Women Trafficking                   124
# dtype: int64

# %% [markdown]
# Counts of every column

# %%
df.value_counts()
# Out:
# State          Year  Rape  Kidnap And Assault  Dowry Deaths  Assault against women  Assault against modesty of women  Domestic violence  Women Trafficking
# UTTARAKHAND    2003  107   134                 93            136                    98                                317                0                    1
#                2004  115   127                 82            143                    110                               405                0                    1
#                2005  133   125                 63            100                    89                                272                0                    1
#                2006  147   183                 80            153                    113                               358                0                    1
#                2007  117   227                 70            146                    63                                463                0                    1
# ...

# %%
# Checking the list of counts of Rape
df["Rape"].value_counts()
# Out:
# Rape
# 0       19
# 2       13
# 1       12
# 3       11
# 4        9
#         ..
# 2891     1
# 1352     1
# 526      1
# 1253     1
# 637      1
# Name: count, Length: 498, dtype: int64

# %%
# seperating numerical and categorical colums in dataset
numcol=[]
catcol=[]

for i in df.columns:
    if df[i].dtype=='object':
        catcol.append(i)
    else:
        numcol.append(i)

# %%
numcol
# Out:
# ['Year',
#  'Rape',
#  'Kidnap And Assault',
#  'Dowry Deaths',
#  'Assault against women',
#  'Assault against modesty of women',
#  'Domestic violence',
#  'Women Trafficking']

# %%
catcol
# Out:
# ['State']

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.isna())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Statistical summary of dataset
df.describe()
# Out:
#               Year         Rape  Kidnap And Assault  Dowry Deaths  \
# count   736.000000   736.000000          736.000000    736.000000
# mean   2011.149457   727.855978         1134.542120    215.692935
# std       6.053453   977.024945         1993.536828    424.927334
# min    2001.000000     0.000000            0.000000      0.000000
# 25%    2006.000000    35.000000           24.750000      1.000000
# 50%    2011.000000   348.500000          290.000000     29.000000
# 75%    2016.000000  1069.000000         1216.000000    259.000000
# max    2021.000000  6337.000000        15381.000000   2524.000000
#
#        Assault against women  Assault against modesty of women  \
# count             736.000000                        736.000000
# mean             1579.115489                        332.722826
# std              2463.962518                        806.024551
# min                 0.000000                          0.000000
# ...

# %%
df.shape
# Out:
# (736, 9)

# %%
df.tail()
# Out:
#             State  Year  Rape  Kidnap And Assault  Dowry Deaths  \
# 731  D & N HAVELI  2021  1250                4083           141
# 732   DAMAN & DIU  2021   315                 904            16
# 733         DELHI  2021     2                   1             0
# 734   LAKSHADWEEP  2021     0                   0             0
# 735    PUDUCHERRY  2021     2                   0             2
#
#      Assault against women  Assault against modesty of women  \
# 731                   2068                               417
# 732                   1851                                10
# 733                      5                                 1
# 734                      1                                 1
# 735                     31                                 3
#
#      Domestic violence  Women Trafficking
# 731               4731                  4
# 732                501                  1
# 733                  9                  0
# ...

# %% [markdown]
# Year Wise Analysis

# %%
def func(total_case_all_years):

    for i in list(df.columns)[2:]:
        total_case_all_years[i]=df.groupby(['Year'])[i].sum()
        
    return total_case_all_years

total_case_all_years=pd.DataFrame()
total_case_all_years=func(total_case_all_years)
total_case_all_years
# Out:
#        Rape  Kidnap And Assault  Dowry Deaths  Assault against women  \
# Year
# 2001  15694               13681          6738                  33622
# 2002  15970               13613          6687                  33497
# 2003  15357               12499          6078                  32450
# 2004  17682               14697          6900                  33966
# 2005  17701               14644          6673                  33413
# 2006  18725               16348          7481                  35899
# 2007  20139               19249          7955                  37866
# 2008  21001               21803          8043                  39802
# 2009  20928               24086          8242                  38159
# 2010  21665               28055          8248                  40012
# 2011  24206               35565          8618                      0
# 2012  24923               38262          8233                  45344
# ...

# %%
pd.DataFrame(total_case_all_years.sum(axis=1),columns=['Total Number of Cases'])
# Out:
#       Total Number of Cases
# Year
# 2001                 128537
# 2002                 128972
# 2003                 128142
# 2004                 140072
# 2005                 139333
# 2006                 149742
# 2007                 170196
# 2008                 182757
# 2009                 190617
# 2010                 200534
# 2011                 178529
# 2012                 235025
# 2013                 298444
# 2014                 333216
# 2015                 323852
# 2016                 335769
# 2017                 305897
# 2018                 314093
# 2019                 333717
# 2020                 302186
# 2021                 348092

# %% [markdown]
# Which was highest reported crime and which one was least ?

# %%
pd.DataFrame( total_case_all_years.sum(axis=0),columns=['Count']).sort_values(by='Count',ascending=False)
# Out:
#                                     Count
# Domestic violence                 1909978
# Assault against women             1162229
# Kidnap And Assault                 835023
# Rape                               535702
# Assault against modesty of women   244884
# Dowry Deaths                       158750
# Women Trafficking                   21156

# %% [markdown]
# State Wise Analysis

# %%
#Creating a dataframe that consists number of cases state wise

def func(state_wise_data):

    for i in list(df.columns)[2:]:
        state_wise_data[i]=df.groupby(['State'])[i].sum()
        
    return state_wise_data

state_wise_data=pd.DataFrame()
state_wise_data=func(state_wise_data)
state_wise_data
# Out:
#                     Rape  Kidnap And Assault  Dowry Deaths  \
# State
# A & N ISLANDS        424                 363            13
# ANDHRA PRADESH     23424               21707          8165
# ARUNACHAL PRADESH   1153                1272             4
# ASSAM              32190               71462          2757
# BIHAR              21006               77687         24428
# CHANDIGARH           795                1547            68
# CHHATTISGARH       25178               16536          1797
# D & N HAVELI        2343                7148           256
# DAMAN & DIU          619                1725            30
# DELHI              13065               31251          1106
# GOA                 1019                 720            23
# GUJARAT             9940               25733           652
# HARYANA            17776               29593          5144
# HIMACHAL PRADESH    4474                4043            76
# JAMMU & KASHMIR     7656               17464           735
# ...

# %% [markdown]
# top 10 highest crime rate state wise

# %%
pd.DataFrame( state_wise_data.sum(axis=1),columns=['Total Count']).sort_values(by='Total Count',ascending=False).head(10)
# Out:
#                 Total Count
# State
# UTTAR PRADESH        529734
# MADHYA PRADESH       413157
# WEST BENGAL          409242
# ANDHRA PRADESH       391123
# RAJASTHAN            379264
# MAHARASHTRA          365632
# ASSAM                291980
# KERALA               202986
# ODISHA               194774
# BIHAR                189886

# %% [markdown]
# UTTAR PRADESH is highest crime rate in india

# %% [markdown]
# top 10 lowest crime rate state wise

# %%
pd.DataFrame( state_wise_data.sum(axis=1),columns=["Total Case"] ).sort_values(by="Total Case").head(10)
# Out:
#                    Total Case
# State
# LAKSHADWEEP                72
# PUDUCHERRY               1793
# A & N ISLANDS            1868
# MIZORAM                  2844
# GOA                      4179
# MEGHALAYA                4294
# MANIPUR                  4390
# ARUNACHAL PRADESH        4822
# CHANDIGARH               5341
# DAMAN & DIU              7015

# %% [markdown]
# LAKSHADWEEP	is lowest rate crime in india

# %% [markdown]
# Out of 7 types of crime which are the states having maximum cases of each type ?

# %%
pd.DataFrame(state_wise_data.idxmax(),columns=["State"])
# Out:
#                                            State
# Rape                              MADHYA PRADESH
# Kidnap And Assault                 UTTAR PRADESH
# Dowry Deaths                       UTTAR PRADESH
# Assault against women             MADHYA PRADESH
# Assault against modesty of women  ANDHRA PRADESH
# Domestic violence                    WEST BENGAL
# Women Trafficking                     TAMIL NADU

# %% [markdown]
# Top 5 States with highest and lowest number of Rape Cases

# %%
print('**Top 5 States with highest number of Rape Cases**')
display(pd.DataFrame(state_wise_data["Rape"]).sort_values(by="Rape",ascending=False).head())

print('\n\n**Top 5 States with lowest number of Rape Cases**')
pd.DataFrame(state_wise_data["Rape"]).sort_values(by="Rape").head()
# Out:
# **Top 5 States with highest number of Rape Cases**
#                  Rape
# State
# MADHYA PRADESH  72808
# UTTAR PRADESH   45694
# RAJASTHAN       43799
# MAHARASHTRA     39252
# ASSAM           32190
# **Top 5 States with lowest number of Rape Cases**
#                Rape
# State
# LAKSHADWEEP      20
# PUDUCHERRY      140
# A & N ISLANDS   424
# DAMAN & DIU     619
# CHANDIGARH      795

# %% [markdown]
# Top 5 States/UT with highest and lowest number of Kidnapping and Assualt Cases

# %%
print('**Top 5 States with highest number of Kidnap And Assault Cases**')
display(pd.DataFrame(state_wise_data["Kidnap And Assault"]).sort_values(by="Kidnap And Assault",ascending=False).head())

print('\n\n**Top 5 States with lowest number of Kidnap And Assault Cases**')
pd.DataFrame(state_wise_data["Kidnap And Assault"]).sort_values(by="Kidnap And Assault").head()
# Out:
# **Top 5 States with highest number of Kidnap And Assault Cases**
#                 Kidnap And Assault
# State
# UTTAR PRADESH               133856
# BIHAR                        77687
# ASSAM                        71462
# MADHYA PRADESH               57485
# RAJASTHAN                    55320
# **Top 5 States with lowest number of Kidnap And Assault Cases**
#                Kidnap And Assault
# State
# LAKSHADWEEP                     1
# MIZORAM                        40
# PUDUCHERRY                    201
# A & N ISLANDS                 363
# MEGHALAYA                     628

# %% [markdown]
# Top 5 States with highest and lowest number of Dowry Deaths Case

# %%
print('**Top 5 States With Highest Number of Dowry Deaths Cases**')
display(pd.DataFrame(state_wise_data["Dowry Deaths"]).sort_values(by="Dowry Deaths",ascending=False).head())

print('\n\n**Top 5 States With Lowest Number of Dowry Deaths Cases**')
pd.DataFrame(state_wise_data["Dowry Deaths"]).sort_values(by="Dowry Deaths").head()
# Out:
# **Top 5 States With Highest Number of Dowry Deaths Cases**
#                 Dowry Deaths
# State
# UTTAR PRADESH          40615
# BIHAR                  24428
# MADHYA PRADESH         13316
# ANDHRA PRADESH          8165
# WEST BENGAL             8075
# **Top 5 States With Lowest Number of Dowry Deaths Cases**
#                    Dowry Deaths
# State
# LAKSHADWEEP                   0
# MANIPUR                       3
# ARUNACHAL PRADESH             4
# MIZORAM                       5
# A & N ISLANDS                13

# %% [markdown]
# Top 5 States with Highest And Lowest Number of Assault against women.

# %%
print('**Top 5 States With Highest Number of Assault against women Cases**')
display(pd.DataFrame(state_wise_data["Assault against women"]).sort_values(by="Assault against women",ascending=False).head())

print('\n\n**Top 5 States With Lowest Number of Dowry Deaths Cases**')
pd.DataFrame(state_wise_data["Assault against women"]).sort_values(by="Assault against women").head()
# Out:
# **Top 5 States With Highest Number of Assault against women Cases**
#                 Assault against women
# State
# MADHYA PRADESH                 152000
# MAHARASHTRA                    107519
# UTTAR PRADESH                   99650
# ANDHRA PRADESH                  92084
# ODISHA                          83473
# **Top 5 States With Lowest Number of Dowry Deaths Cases**
#                Assault against women
# State
# LAKSHADWEEP                       23
# A & N ISLANDS                    558
# PUDUCHERRY                       870
# CHANDIGARH                       954
# MANIPUR                         1131

# %% [markdown]
# EDA

# %%
crime_trend = df.groupby('Year').sum()

plt.figure(figsize=(14, 7))
sns.lineplot(data=crime_trend)
plt.title('Trend of Crimes Against Women (2001-2021)')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
crime_by_state = df.groupby('State')['Rape'].sum().sort_values(ascending=False)
print("Top 10 States by Number of Rape Cases:")
print(crime_by_state.head(10))
# Out:
# Top 10 States by Number of Rape Cases:
# State
# MADHYA PRADESH    72808
# UTTAR PRADESH     45694
# RAJASTHAN         43799
# MAHARASHTRA       39252
# ASSAM             32190
# WEST BENGAL       29486
# CHHATTISGARH      25178
# ODISHA            24810
# KERALA            24184
# ANDHRA PRADESH    23424
# Name: Rape, dtype: int64

# %%
# Distribution of rape cases
plt.figure(figsize=(10, 6))
sns.histplot(df['Rape'], kde=True)
plt.title('Distribution of Rape Cases')
plt.xlabel('Number of Rape Cases')
plt.show()

# %%
# Box plot of rape cases by state
plt.figure(figsize=(15, 6))
sns.boxplot(x='State', y='Women Trafficking', data=df)
plt.title('Distribution of Women Trafficking Cases by State')
plt.xticks(rotation=90)
plt.show()

# %%
# Scatter plot of rape cases vs dowry deaths
plt.figure(figsize=(10, 6))
plt.scatter(df['Dowry Deaths'], df['Rape'])
plt.title('Rape Cases vs Dowry Deaths')
plt.xlabel('Dowry Deaths')
plt.ylabel('Rape Cases')
plt.show()

# %%
# Pie chart of crime distribution for the latest year
latest_year = df['Year'].max()
latest_data = df[df['Year'] == latest_year].sum()
crime_types = ['Rape', 'Kidnap And Assault', 'Dowry Deaths', 'Assault against women', 
               'Assault against modesty of women', 'Domestic violence', 'Women Trafficking']
plt.figure(figsize=(10, 6))
plt.pie(latest_data[crime_types], labels=crime_types, autopct='%1.1f%%')
plt.title(f'Distribution of Crime Types in {latest_year}')
plt.show()

# %%
plt.figure(figsize=(15, 7.5))
sns.violinplot(x='Year', y='Kidnap And Assault', data=df,palette="pink")
plt.title('Distribution of Kidnap And Assault Cases for in India (Violin Plot)')
plt.xlabel('Year')
plt.ylabel('Kidnap And Assault')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.barplot(data=df[df['Year'] == 2020], y='State', x='Assault against women')
plt.title('Comparion Assault against women Across India in 2020')
plt.xticks(rotation=90)
plt.show()

# %%
from scipy.stats import zscore

# %%
df.skew(numeric_only=True)
# Out:
# Year                               -0.037077
# Rape                                2.283916
# Kidnap And Assault                  3.127420
# Dowry Deaths                        3.373033
# Assault against women               2.259985
# Assault against modesty of women    4.878237
# Domestic violence                   2.238271
# Women Trafficking                   4.049240
# dtype: float64

# %%
# checking out outliners of data to check whether the skewness in present in our data or not
plt.figure(figsize=(15,7.5))
plt.suptitle("Visualizing the outliers")            #suptitle is used to give title to entire graphs
pltno=1     
for i in numcol:
    if pltno<=8:
        plt.subplot(4,2,pltno)
        sns.boxplot(df[i],color="skyblue")
    pltno=pltno+1
plt.tight_layout()

# %%
features=df[["Year","Rape","Kidnap And Assault", "Dowry Deaths", "Assault against women","Assault against modesty of women", "Domestic violence", "Women Trafficking"]]
z=np.abs(zscore(features))

# %%
z
# Out:
#          Year      Rape  Kidnap And Assault  Dowry Deaths  \
# 0    1.677779  0.146610            0.185496      0.481132
# 1    1.677779  0.711679            0.541889      0.507945
# 2    1.677779  0.091302            0.032398      0.369003
# 3    1.677779  0.164021            0.309481      1.514952
# 4    1.677779  0.236740            0.483662      0.343099
# ..        ...       ...                 ...           ...
# 731  1.628367  0.534786            1.480014      0.175898
# 732  1.628367  0.422852            0.115723      0.470266
# 733  1.628367  0.743430            0.568995      0.507945
# 734  1.628367  0.745478            0.569497      0.507945
# 735  1.628367  0.743430            0.569497      0.503235
#
#      Assault against women  Assault against modesty of women  \
# 0                 0.797991                          2.406372
# 1                 0.609643                          0.409351
# 2                 0.296113                          0.408110
# ...

# %%
newdf=df[(z<=3).all(axis=1)]
newdf
# Out:
#                  State  Year  Rape  Kidnap And Assault  Dowry Deaths  \
# 0       ANDHRA PRADESH  2001   871                 765           420
# 1    ARUNACHAL PRADESH  2001    33                  55             0
# 2                ASSAM  2001   817                1070            59
# 3                BIHAR  2001   888                 518           859
# 4         CHHATTISGARH  2001   959                 171            70
# ..                 ...   ...   ...                 ...           ...
# 731       D & N HAVELI  2021  1250                4083           141
# 732        DAMAN & DIU  2021   315                 904            16
# 733              DELHI  2021     2                   1             0
# 734        LAKSHADWEEP  2021     0                   0             0
# 735         PUDUCHERRY  2021     2                   0             2
#
#      Assault against women  Assault against modesty of women  \
# 0                     3544                              2271
# ...

# %%
dataloss=((736-646)/736)*100
dataloss
# Out:
# 12.228260869565217

# %%
# Assuming `features` is the subset of numerical columns you are analyzing
Q1 = features.quantile(0.25)
Q3 = features.quantile(0.75)
IQR = Q3 - Q1

# Filter the DataFrame to remove outliers across all numerical columns
df1 = df[~((features < (Q1 - 1.5 * IQR)) | (features > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (507, 10)

# %%
dataloss1=((736-507)/736)*100
dataloss1
# Out:
# 31.11413043478261

# %%
# checking out distribution of data to check whether the skewness in present in our data or not
plt.figure(figsize=(15,7.5))
plt.suptitle("Visualizing the distribution of data")
pltno=1     
for i in numcol:
    if pltno<=8:
        plt.subplot(4,2,pltno)
        sns.kdeplot(df[i],shade=True,color="purple")
    pltno=pltno+1
plt.tight_layout()

# %%
newdf.skew(numeric_only=True)
# Out:
# Year                                0.071439
# Rape                                1.780797
# Kidnap And Assault                  2.836773
# Dowry Deaths                        2.769000
# Assault against women               1.849720
# Assault against modesty of women    3.221297
# Domestic violence                   2.065848
# Women Trafficking                   4.210868
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# Year                               -0.037077
# Rape                                2.283916
# Kidnap And Assault                  3.127420
# Dowry Deaths                        3.373033
# Assault against women               2.259985
# Assault against modesty of women    4.878237
# Domestic violence                   2.238271
# Women Trafficking                   4.049240
# dtype: float64

# %%
skew1=['Year','Rape','Kidnap And Assault','Dowry Deaths','Assault against women','Assault against modesty of women','Domestic violence','Women Trafficking]
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer(method='yeo-johnson')
newdf[skew1]=PT.fit_transform(newdf[skew1])

# %%
# Checking the skewness after using yeo-johnson method
newdf[skew1].skew()
# Out:
# Year                                0.010673
# Rape                               -0.024124
# Kidnap And Assault                 -0.001116
# Dowry Deaths                        0.039752
# Assault against modesty of women    0.011156
# Domestic violence                  -0.019260
# Women Trafficking                   0.435401
# dtype: float64

# %%
plt.figure(figsize=(15,20))
plotnumber=1
for column in newdf[skew1]:
    if plotnumber<=9:
        ax=plt.subplot(4,2,plotnumber)
        sns.distplot(newdf[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
sns.heatmap(newdf.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
catcol=newdf.select_dtypes('object').columns
catcol
# Out:
# Index(['State'], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
newdf[catcol]=OE.fit_transform(newdf[catcol])

# %%
x=newdf.iloc[:,:-1]

# %%
y=newdf.iloc[:,-1]

# %%
x.shape
# Out:
# (646, 8)

# %%
y.shape
# Out:
# (646,)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Checking R2 score for Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(xtrain,ytrain)

# prediction
predRFR=RFR.predict(xtest)
rf=r2_score(ytest,predRFR)
print('R2_Score:',rf)
print('MAE:',metrics.mean_absolute_error(ytest, predRFR))
print('MSE:',metrics.mean_squared_error(ytest, predRFR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predRFR)))

# Visualizing the predicted values
sns.regplot(x=ytest,y=predRFR,color="crimson")
plt.show()
# Out:
# R2_Score: 0.6847229481363343
# MAE: 0.33762679785563127
# MSE: 0.3270774100935232
# RMSE: 0.571906819415124

# %%
# Checking R2 score for Decision Tree Regressor
DTR=DecisionTreeRegressor()
DTR.fit(xtrain,ytrain)

# prediction
predDTR=DTR.predict(xtest)
dt=r2_score(ytest,predDTR)
print('R2_Score:',dt)
print('MAE:',metrics.mean_absolute_error(ytest, predDTR))
print('MSE:',metrics.mean_squared_error(ytest, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predDTR)))

# Visualizing the predicteed values
sns.regplot(x=ytest,y=predDTR,color="purple")
plt.show()
# Out:
# R2_Score: 0.485260205272242
# MAE: 0.33545035541271995
# MSE: 0.5340057512477315
# RMSE: 0.7307569713986528

# %%
# Checking R2 score for GradientBoosting Regressor
GB=GradientBoostingRegressor()
GB.fit(xtrain,ytrain)

# prediction
predGB=GB.predict(xtest)
gbr=r2_score(ytest,predGB)
print('R2_Score:',gbr)

# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(ytest, predGB))
print('MSE:',metrics.mean_squared_error(ytest, predGB))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predGB)))

# Visualizing the predicted values
sns.regplot(x=ytest,y=predGB,color="green")
plt.show()
# Out:
# R2_Score: 0.673492427636827
# MAE: 0.39097771039812373
# MSE: 0.3387282725247332
# RMSE: 0.5820036705423198

# %%
# Checking R2 score for BaggingRegressor

BR=BaggingRegressor()
BR.fit(xtrain,ytrain)

# prediction
predBR=BR.predict(xtest)
bgr=r2_score(ytest,predBR)
print('R2_Score:',bgr)

# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(ytest, predBR))
print('MSE:',metrics.mean_squared_error(ytest, predBR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predBR)))

# Visualizing the predicted values
sns.regplot(x=ytest,y=predBR,color="crimson")
plt.show()
# Out:
# R2_Score: 0.6474867785691192
# MAE: 0.36424726552054865
# MSE: 0.3657072749436759
# RMSE: 0.6047373603008797

# %%
# Checking R2 score for XGB Regressor
from xgboost import XGBRegressor as xgb

XGB=xgb()
XGB.fit(xtrain,ytrain)

# prediction
predXGB=XGB.predict(xtest)
xgb1=r2_score(ytest,predXGB)
print('R2_Score:',xgb1)

# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(ytest, predXGB))
print('MSE:',metrics.mean_squared_error(ytest, predXGB))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predXGB)))

# Visualizing the predicted values
sns.regplot(x=ytest,y=predXGB,color="crimson")
plt.show()
# Out:
# R2_Score: 0.6277916885965464
# MAE: 0.3678660966196837
# MSE: 0.38613952328433093
# RMSE: 0.621401257871539

# %%
# Checking R2 score for Extra Trees Regressor

XT=ExtraTreesRegressor()
XT.fit(xtrain,ytrain)

# prediction
predXT=XT.predict(xtest)
etr=r2_score(ytest,predXT)
print('R2_Score:',etr)

# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(ytest, predXT))
print('MSE:',metrics.mean_squared_error(ytest, predXT))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predXT)))

# Visualizing the predicted values
sns.regplot(x=ytest,y=predXT,color="crimson")
plt.show()
# Out:
# R2_Score: 0.6618218359250854
# MAE: 0.37157597936663284
# MSE: 0.35083567738903043
# RMSE: 0.5923138335283336

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking cv score for Random Forest Regressor
rf_cv=cross_val_score(RFR,x,y,cv=5).mean()
print(rf_cv)
# Out:
# 0.5425711686637197

# %%
# Checking cv score for Decision Tree Regressor
dt_cv=cross_val_score(DTR,x,y,cv=5).mean()
print(dt_cv)
# Out:
# 0.08972101495875758

# %%
# Checking cv score for Gradient Boosting Regressor
gb_cv=cross_val_score(GB,x,y,cv=5).mean()
print(gb_cv)
# Out:
# 0.5349508984144987

# %%
# Checking cv score for Bagging Regressor
br_cv=cross_val_score(BR,x,y,cv=5).mean()
print(br_cv)
# Out:
# 0.5275178715744816

# %%
# Checking cv score for XGBRegressor
xgb_cv=cross_val_score(XGB,x,y,cv=5).mean()
print(xgb_cv)
# Out:
# 0.23064135974760078

# %%
# Checking cv score for ExtraTreesRegressor
et_cv=cross_val_score(XT,x,y,cv=5).mean()
print(et_cv)
# Out:
# 0.4829672410728511

# %%
Model_list=['Random Forest Regressor','Decision Tree Regressor','Gradient Boosting Regressor','Bagging Regressor','XGB Regressor','Extra Trees Regressor']

# %%
accuracyscore=[rf,dt,gbr,bgr,xgb1,etr]

# %%
crossval=[rf_cv,dt_cv,gb_cv,br_cv,xgb_cv,et_cv]

# %%
models=pd.DataFrame({})
models['Regressor']=Model_list
models['Accuracy_score']=accuracyscore
models['crossval']=crossval

# %%
models
# Out:
#                      Regressor  Accuracy_score  crossval
# 0      Random Forest Regressor        0.684723  0.542571
# 1      Decision Tree Regressor        0.485260  0.089721
# 2  Gradient Boosting Regressor        0.673492  0.534951
# 3            Bagging Regressor        0.647487  0.527518
# 4                XGB Regressor        0.627792  0.230641
# 5        Extra Trees Regressor        0.661822  0.482967

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {
    'n_estimators': [100, 200, 300],      
    'max_depth': [10, 20, 30],            
    'min_samples_split': [2, 5, 10],      
    'min_samples_leaf': [1, 2, 4]         
}

# %%
GCV=GridSearchCV(xgb(),parameter,cv=5)

# %%
GCV.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
GCV.best_params_
# Out:
# {'max_depth': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
Final_model2=xgb(max_depth=None,min_samples_split=2,n_estimators=300)
Final_model2.fit(xtrain,ytrain)
pred=Final_model2.predict(xtest)
print('R2_Score',r2_score(ytest,pred))
print('MAE',metrics.mean_absolute_error(ytest,pred))
print('MSE',metrics.mean_squared_error(ytest,pred))
print('RMSE',np.sqrt(metrics.mean_squared_error(ytest,pred)))
sns.regplot(x=ytest,y=pred,color='r')
# Out:
# R2_Score 0.6274426866832417
# MAE 0.3680946106385983
# MSE 0.38650158782802874
# RMSE 0.6216925187164702
# <Axes: xlabel='Women Trafficking'>
